# %% [markdown]
# <a href="https://colab.research.google.com/github/YuGa-2005/genai-apex/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyAmOdZWxCuZv4iR99IvDSz2qbqI3nM1Mqc")

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
res=model.generate_content("List out the districts in tamilnadu")

# %%
res.text
# Out:
# '1. Ariyalur\n2. Chennai\n3. Coimbatore\n4. Cuddalore\n5. Dharmapuri\n6. Dindigul\n7. Erode\n8. Kanchipuram\n9. Kanyakumari\n10. Karur\n11. Krishnagiri\n12. Madurai\n13. Mayiladuthurai\n14. Nagapattinam\n15. Namakkal\n16. Nilgiris\n17. Perambalur\n18. Pudukkottai\n19. Ramanathapuram\n20. Ranipet\n21. Salem\n22. Sivagangai\n23. Tenkasi\n24. Thanjavur\n25. Theni\n26. Thoothukudi\n27. Tiruchirappalli\n28. Tirunelveli\n29. Tiruppur\n30. Tiruvallur\n31. Tiruvannamalai\n32. Tindivanam\n33. Vellore\n34. Villupuram\n35. Virudhunagar'

# %%
vision_model=genai.GenerativeModel("gemini-pro-vision")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image
img=Image.open("/content/image1.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=403x125>

# %%
vision_model.generate_content(["explain this image",img]).text
# Out:
# "That's a photograph of two women's under-19 cricket teams.  The image shows the Punjab team who defeated the Tamil Nadu team in a match.\n\nSpecifically:\n\n* **The Winning Team:** The Punjab Under-19 women's cricket team are posing for a group photo. They are wearing matching yellow and blue uniforms.\n\n* **The Losing Team:** Members of the Tamil Nadu Under-19 women's team are interspersed within the Punjab team photo.  They also wear similar uniforms.\n\n* **The Caption:** The caption at the bottom indicates the score of the match, stating that Punjab won by 38 runs in a Women's Under-19 T20 Trophy HBL League match.\n\nThe photo likely commemorates the victory of the Punjab team.  The players appear happy and proud of their accomplishment.\n"

# %%
vision_model.generate_content(["explain who are the persons in image",img]).text
# Out:
# "The image shows two women's under-19 cricket teams, Punjab and Tamil Nadu, after a match.  The Punjab team is shown in the front row and in most of the back row, indicated by the caption stating they defeated Tamil Nadu.  There are multiple players in each team, with no individual players identified by name.\n"

# %%
vision_model=genai.GenerativeModel("gemini-pro-vision")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image
img=Image.open("/content/football teams.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x800>

# %%
vision_model.generate_content(["explain this image",img]).text
# Out:
# 'That\'s a team photo of FC Barcelona\'s football (soccer) team.  The image shows the players lined up in two rows before a Champions League match.  \n\nSpecifically, we see:\n\n* **Players in Barcelona\'s kit:**  Most of the image is filled with players wearing the team\'s iconic dark blue and red striped jerseys, with the "Rakuten" sponsor prominently displayed.  This indicates the photograph was taken during the period Rakuten sponsored the club.\n* **Goalkeeper:**  A goalkeeper in a yellow and blue kit is visible on the far left.\n* **Lionel Messi:**  Lionel Messi, a legendary player for Barcelona at the time, is easily recognizable in the front row.\n* **Various other players:**  A number of other Barcelona players from that era are in the photo.  Precise identification of every player would require more information.\n* **Setting:** The background indicates a large stadium, likely during a Champions League match, given the visible Champions League branding on some of the players
# ...
